# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 723.1/723.1 kB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 12.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 21.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 11.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 2.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os
from  IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo checks
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 28.9/107.7 GB disk)
#
# OS                  Linux-6.1.58+-x86_64-with-glibc2.35
# Environment         Colab
# Python              3.10.12
# Install             pip
# RAM                 12.67 GB
# CPU                 Intel Xeon 2.20GHz
# CUDA                None
#
# matplotlib          ✅ 3.7.1>=3.3.0
# opencv-python       ✅ 4.8.0.76>=4.6.0
# pillow              ✅ 9.4.0>=7.1.2
# pyyaml              ✅ 6.0.1>=5.3.1
# requests            ✅ 2.31.0>=2.23.0
# scipy               ✅ 1.11.4>=1.4.1
# torch               ✅ 2.2.1+cu121>=1.8.0
# torchvision         ✅ 0.17.1+cu121>=0.9.0
# tqdm                ✅ 4.66.2>=4.64.0
# psutil              ✅ 5.9.5
# py-cpuinfo          ✅ 9.0.0
# thop                ✅ 0.1.1-2209072238>=0.1.1
# pandas              ✅ 1.5.3>=1.1.4
# seaborn             ✅ 0.13.1>=0.11.0

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="wA7A1p4UvM0dOahuJsOx")
project = rf.workspace("liyan-ljbi2").project("leafdetection-gs1yz")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.1.34, to fix: `pip install ultralytics==8.0.196`

# %%
# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=25 imgsz=480
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 45.3MB/s]
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

image_path = '/content/runs/detect/train2/confusion_matrix.png'
img = mpimg.imread(image_path)

# Increase the figure size
plt.figure(figsize=(10, 8))

# Display the image
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

image_path = '/content/runs/detect/train2/results.png'
img = mpimg.imread(image_path)

# Increase the figure size
plt.figure(figsize=(10, 8))

# Display the image
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train2/weights/best.pt data={dataset.location}/data.yaml
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/leafdetection-1/valid/labels.cache... 46 images, 0 backgrounds, 0 corrupt: 100% 46/46 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:31<00:00, 10.38s/it]
#                    all         46        799      0.759      0.818      0.843      0.576
#               Bad_Leaf         46         94      0.666      0.681      0.721      0.402
#                   Leaf         46        705      0.852      0.956      0.966       0.75
# Speed: 7.6ms preprocess, 650.1ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=detect source = /content/leafdetection-1/test/images mode=predict model=/content/runs/detect/train2/weights/best.pt conf=0.5 data={dataset.location}/data.yaml
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/34 /content/leafdetection-1/test/images/20240317_279_800_600_2_jpg.rf.bc8dfc87830ff160a9d49a6340fa1e6d.jpg: 480x480 2 Leafs, 416.7ms
# image 2/34 /content/leafdetection-1/test/images/20240319_279_640_480__jpg.rf.e7104ce5ee01e6db050497a0e5771ecb.jpg: 480x480 4 Leafs, 356.0ms
# image 3/34 /content/leafdetection-1/test/images/20240319_279_800_600_2_jpg.rf.38ecd64841628068a2580b34a7aefa37.jpg: 480x480 4 Leafs, 347.0ms
# image 4/34 /content/leafdetection-1/test/images/20240321_285_640_480_2-1-_jpg.rf.191d5c1ff6c2da6fbec30ed010c54c01.jpg: 480x480 5 Leafs, 352.7ms
# image 5/34 /content/leafdetection-1/test/images/20240323_286_640_480_-1-_jpg.rf.7361ba7b46feb460e97b638d5154b8d3.jpg: 480x480 6 Leafs, 347.6ms
# ...

# %%
import glob

from IPython.display import Image, display

for image_path in glob.glob(f'/content/runs/detect/predict/*.jpg'):
  display(Image(filename=image_path, height=600))
  print("\n")

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

image_path = '/content/runs/detect/train2/F1_curve.png'
img = mpimg.imread(image_path)

# Display the image
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

image_path = '/content/runs/detect/train2/PR_curve.png'
img = mpimg.imread(image_path)

# Display the image
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

image_path = '/content/runs/detect/train2/results.png'
img = mpimg.imread(image_path)

# Display the image
plt.imshow(img)
plt.axis('off')
plt.show()
